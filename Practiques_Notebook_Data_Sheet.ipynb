# %% [markdown]
# # Pràctíques amb el Markdown
# ### Utilitzar la fulla de Markdown cheat sheet

# %% [markdown]
# **Format en bold _i ara bold i italic_ i només bold** i tornem a la normalitat

# %% [markdown]
# _Italit_ __bold__ ___Italic i bold___ fet amb _
#
# *Italic* **bold** ***Italic i bold*** fet amb *

# %% [markdown]
# >Extended quotation
#
# >Text

# %% [markdown]
# * Llista Ítem 1
# * Llista Ítem 2
#     + Subllista Item 1
#         + Subllista Ítem 1

# %% [markdown]
# 1. Ítem primer
# 2. Ïtem 2n.
#
#     2.1. Subítem 1r
#     2.2. Subítem 2n

# %% [markdown]
# ~~Text Strikethrough~~

# %% [markdown]
# -[x]completed task
#
# -[]incompleted

# %% [markdown]
# :+1:

# %% [markdown]
# :camel:

# %% [markdown]
# ![gat1.jpg](attachment:gat1.jpg)

# %% [markdown]
# ![gat](https://imagenes.20minutos.es/files/image_656_370/uploads/imagenes/2021/12/04/pisco-y-el-gato-con-botas.jpeg)

# %%
# %system date
# Out:
# ['La fecha actual es: 24/01/2022 ', 'Escriba la nueva fecha: (dd-mm-aa) ']

# %% [markdown]
# |títol 1|titol 2|titol 3|
# |:--------|:-------------------|-------:|
# |un |dos|tres|
# |quatre|cinc|sis i settttt|

# %% [markdown]
# [Press here to go to Google web][www.google.com]

# %% [markdown]
# ### Proves amb Python i Jupyter Notebook

# %%
3+4
# Out:
# 7

# %%
c= 'oleeeee\n'
print (c*3)
# Out:
# oleeeee
# oleeeee
# oleeeee

# %% [markdown]
# ![image.png](attachment:image.png)
